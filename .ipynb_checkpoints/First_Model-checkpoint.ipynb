# %% [markdown]
# # AI/ ML project
# To develop and deploy a solution using AI. Train a deep learning image classification model that is able to recognise the classifications of the car images.
#
# <b>Dataset</b> (Stanford Cars Dataset) is downloaded from [Kaggle (images)](https://www.kaggle.com/datasets/peterjun/car196) and [Kaggle (mat file)](https://www.kaggle.com/datasets/jessicali9530/stanford-cars-dataset), as the [Standford link](https://ai.stanford.edu/~jkrause/cars/car_dataset.html) for this dataset is inactive. I have also tried to download with [tensorflow](https://www.tensorflow.org/datasets/catalog/cars196) to no avail as the standford link is down. The images files were already split into test and train folders.
#
# For this project I have chosen to work on Tensorflow framework instead of Pytorch as I'm more familiar with Tensorflow, also I have chosen to use a pre-trained open-source classifier models as it helps to reduce development time and resources.
#
# I'll start this project off by looking at the different pretrained models. I'm looking at several models of which to be used for this project:
# - Lenet (1998) ([Source](https://www.analyticsvidhya.com/blog/2021/03/the-architecture-of-lenet-5/))
#     - 5 layers with learnable parameters
#     - 3 convolution layers with a combination of average pooling
#     - 2 fully connected layers
#     - softmax classifier
# - AlexNet (2012) ([Source](https://www.analyticsvidhya.com/blog/2021/03/introduction-to-the-architecture-of-alexnet/))
#     - 8 layers with learnable parameters
#     - 5 layers with a combination of max pooling
#     - 3 fully connected layers using Relu activation except the output layer.
# - VGG16 (2014) ([Source](https://www.analyticsvidhya.com/blog/2020/08/top-4-pre-trained-models-for-image-classification-with-python-code/#h-very-deep-convolutional-networks-for-large-scale-image-recognition-vgg-16))
#     - 13 Convolutional Layers
#     - 5 Pooling Layers
#     - 3 Dense Layers
# - MobileNetV3 (2019)
#     - two version - large and small ([paper Source](https://arxiv.org/pdf/1905.02244v5))
#     - training small version on my computer would be more suitable ([code Source](https://github.com/xiaolai-sqlai/mobilenetv3/blob/adc0ca87e1dd8136cd000ae81869934060171689/mobilenetv3.py#L75))
# - EfficientNet (2019) ([Source](https://arxiv.org/abs/1905.11946v5))
#     - scaling method that uniformly scales all dimensions of depth/width/resolution using a compound coefficient. ([Source](https://paperswithcode.com/method/efficientnet))
# - SLCA++ (2023) ([Source](https://arxiv.org/abs/2408.08295))
#     - Slow Learner (SL): This component selectively reduces the learning rate of backbone parameters to balance the retention of pre-trained knowledge with the acquisition of new task-specific information.
#     - Classifier Alignment (CA): CA aligns disjoint classification layers in a post-hoc manner by modeling class-wise distributions, thereby mitigating biases between tasks or classes.
#     - <b>From my understanding</b> SLCA relies on a pre-trained backbone model to extract features so either EfficientNet, MobileNet or resNet; Probably not going to experiment with this till i understand the topic better.
#
# From this short reading, my understanding from model VGG16 to older models are outdated and was consider a break through when they were introduced but currently standards should be efficientNet and MobileNet.

# %% [markdown]
# ### MobileNetV3 on ImageNet
# ![image.png](attachment:3678d947-8ab9-49cd-bfde-0ae5792f553d.png)
#
# ### EfficientNet on ImageNet
# ![image.png](attachment:74854c4c-3f99-447b-92db-a76ba5b75164.png)
#
# ### SLCA++ on ImageNet
# ![image.png](attachment:9d1cb845-f54b-4581-b90f-e3308e4e17a7.png)
#
# ### My computer specs:
# - NVIDIA GeForce RTX 3060 Ti
# - AMD Ryzen 5 5600X 6-Core
# - 16GB ram
#
# I have decided to choose EfficientNet-B0 as the 5M params is pretty lighweight for my small GPU, thou MobileNetV3 have around the same or less params the accuracy doesn't seems to be much better than Efficient b0 so for this project i'll test out EfficientNet-B0 and if i have time i would like to test the other models too.

# %% [markdown]
# ### Install libraries

# %% [markdown]
# ### Importing Libraries

# %%
pip install scipy torch torchvision tensorflow_datasets matplotlib scikit-learn
# Out:
# Requirement already satisfied: scipy in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (1.14.0)
# Requirement already satisfied: torch in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (2.3.1)
# Requirement already satisfied: torchvision in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (0.18.1)
# Requirement already satisfied: tensorflow_datasets in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (4.9.7)
# Requirement already satisfied: matplotlib in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: scikit-learn in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from scipy) (1.26.4)
# Requirement already satisfied: filelock in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.5.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: absl-py in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (2.1.0)
# Requirement already satisfied: click in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (8.1.7)
# Requirement already satisfied: dm-tree in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (0.1.8)
# Requirement already satisfied: immutabledict in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (4.2.1)
# Requirement already satisfied: promise in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (4.25.3)
# Requirement already satisfied: psutil in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (5.9.8)
# Requirement already satisfied: pyarrow in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (16.1.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (2.32.3)
# Requirement already satisfied: simple-parsing in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (1.16.1)
# Requirement already satisfied: termcolor in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (2.4.0)
# Requirement already satisfied: toml in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: tqdm in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (4.66.4)
# Requirement already satisfied: wrapt in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow_datasets) (1.16.0)
# Requirement already satisfied: etils>=1.9.1 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: importlib_resources in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (6.4.5)
# Requirement already satisfied: zipp in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (3.21.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from click->tensorflow_datasets) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from simple-parsing->tensorflow_datasets) (0.16)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in c:\users\light\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-metadata->tensorflow_datasets) (1.66.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy.io, h5py, os, torch, torchvision, glob, re, keras, os, json
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from keras import layers
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import Sequential, Model, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from torchvision.datasets.utils import download_url

# %% [markdown]
# # Data Preprocessing

# %%
# loading the mat file
data = scipy.io.loadmat("data/cars_annos.mat")

# %% [markdown]
# looking through tfds to download for car196 dataset

# %%
tfds.list_builders()
# Out:
# ['abstract_reasoning',
#  'accentdb',
#  'aeslc',
#  'aflw2k3d',
#  'ag_news_subset',
#  'ai2_arc',
#  'ai2_arc_with_ir',
#  'ai2dcaption',
#  'aloha_mobile',
#  'amazon_us_reviews',
#  'anli',
#  'answer_equivalence',
#  'arc',
#  'asqa',
#  'asset',
#  'assin2',
#  'asu_table_top_converted_externally_to_rlds',
#  'austin_buds_dataset_converted_externally_to_rlds',
#  'austin_sailor_dataset_converted_externally_to_rlds',
#  'austin_sirius_dataset_converted_externally_to_rlds',
#  'bair_robot_pushing_small',
#  'bc_z',
#  'bccd',
#  'beans',
#  'bee_dataset',
#  'beir',
#  'berkeley_autolab_ur5',
#  'berkeley_cable_routing',
#  'berkeley_fanuc_manipulation',
#  'berkeley_gnm_cory_hall',
#  'berkeley_gnm_recon',
#  'berkeley_gnm_sac_son',
#  'berkeley_mvp_converted_externally_to_rlds',
#  'berkeley_rpt_converted_externally_to_rlds',
#  'big_patent',
#  'bigearthnet',
#  'billsum',
#  'binarized_mnist',
#  'binary_alpha_digits',
#  'ble_wind_field',
#  'blimp',
#  'booksum',
#  'bool_q',
#  'bot_adversarial_dialogue',
#  'bridge',
#  'bridge_data_msr',
#  'bucc',
#  'c4',
#  'c4_wsrs',
#  'caltech101',
#  'caltech_birds2010',
#  'caltech_birds2011',
#  'cardiotox',
#  'cars196',
#  'cassava',
#  'cats_vs_dogs',
#  'celeb_a',
#  'celeb_a_hq',
#  'cfq',
#  'cherry_blossoms',
#  'chexpert',
#  'cifar10',
#  'cifar100',
#  'cifar100_n',
#  'cifar10_1',
#  'cifar10_corrupted',
#  'cifar10_h',
#  'cifar10_n',
#  'citrus_leaves',
#  'cityscapes',
#  'civil_comments',
#  'clevr',
#  'clic',
#  'clinc_oos',
#  'cmaterdb',
#  'cmu_franka_exploration_dataset_converted_externally_to_rlds',
#  'cmu_play_fusion',
#  'cmu_stretch',
#  'cnn_dailymail',
#  'coco',
#  'coco_captions',
#  'coil100',
#  'colorectal_histology',
#  'colorectal_histology_large',
#  'columbia_cairlab_pusht_real',
#  'common_voice',
#  'conll2002',
#  'conll2003',
#  'conq_hose_manipulation',
#  'controlled_noisy_web_labels',
#  'coqa',
#  'corr2cause',
#  'cos_e',
#  'cosmos_qa',
#  'covid19',
#  'covid19sum',
#  'crema_d',
#  'criteo',
#  'cs_restaurants',
#  'curated_breast_imaging_ddsm',
#  'cycle_gan',
#  'd4rl_adroit_door',
#  'd4rl_adroit_hammer',
#  'd4rl_adroit_pen',
#  'd4rl_adroit_relocate',
#  'd4rl_antmaze',
#  'd4rl_mujoco_ant',
#  'd4rl_mujoco_halfcheetah',
#  'd4rl_mujoco_hopper',
#  'd4rl_mujoco_walker2d',
#  'dart',
#  'databricks_dolly',
#  'davis',
#  'deep1b',
#  'deep_weeds',
#  'definite_pronoun_resolution',
#  'dementiabank',
#  'diabetic_retinopathy_detection',
#  'diamonds',
#  'dices',
#  'div2k',
#  'dlr_edan_shared_control_converted_externally_to_rlds',
#  'dlr_sara_grid_clamp_converted_externally_to_rlds',
#  'dlr_sara_pour_converted_externally_to_rlds',
#  'dmlab',
#  'dobbe',
#  'doc_nli',
#  'dolma',
#  'dolphin_number_word',
#  'domainnet',
#  'downsampled_imagenet',
#  'drop',
#  'dsprites',
#  'dtd',
#  'duke_ultrasound',
#  'e2e_cleaned',
#  'efron_morris75',
#  'emnist',
#  'eraser_multi_rc',
#  'esnli',
#  'eth_agent_affordances',
#  'eurosat',
#  'fashion_mnist',
#  'flic',
#  'flores',
#  'fmb',
#  'food101',
#  'forest_fires',
#  'fractal20220817_data',
#  'fuss',
#  'gap',
#  'geirhos_conflict_stimuli',
#  'gem',
#  'genomics_ood',
#  'german_credit_numeric',
#  'gigaword',
#  'glove100_angular',
#  'glue',
#  'goemotions',
#  'gov_report',
#  'gpt3',
#  'gref',
#  'groove',
#  'grounded_scan',
#  'gsm8k',
#  'gtzan',
#  'gtzan_music_speech',
#  'hellaswag',
#  'higgs',
#  'hillstrom',
#  'horses_or_humans',
#  'howell',
#  'i_naturalist2017',
#  'i_naturalist2018',
#  'i_naturalist2021',
#  'iamlab_cmu_pickup_insert_converted_externally_to_rlds',
#  'imagenet2012',
#  'imagenet2012_corrupted',
#  'imagenet2012_fewshot',
#  'imagenet2012_multilabel',
#  'imagenet2012_real',
#  'imagenet2012_subset',
#  'imagenet_a',
#  'imagenet_lt',
#  'imagenet_pi',
#  'imagenet_r',
#  'imagenet_resized',
#  'imagenet_sketch',
#  'imagenet_v2',
#  'imagenette',
#  'imagewang',
#  'imdb_reviews',
#  'imperialcollege_sawyer_wrist_cam',
#  'io_ai_tech',
#  'irc_disentanglement',
#  'iris',
#  'istella',
#  'jaco_play',
#  'kaist_nonprehensile_converted_externally_to_rlds',
#  'kddcup99',
#  'kitti',
#  'kmnist',
#  'kuka',
#  'laion400m',
#  'lambada',
#  'lfw',
#  'librispeech',
#  'librispeech_lm',
#  'libritts',
#  'ljspeech',
#  'lm1b',
#  'locomotion',
#  'lost_and_found',
#  'lsun',
#  'lvis',
#  'malaria',
#  'maniskill_dataset_converted_externally_to_rlds',
#  'math_dataset',
#  'math_qa',
#  'mctaco',
#  'media_sum',
#  'mimic_play',
#  'mlqa',
#  'mnist',
#  'mnist_corrupted',
#  'movie_lens',
#  'movie_rationales',
#  'movielens',
#  'moving_mnist',
#  'mrqa',
#  'mslr_web',
#  'mt_opt',
#  'mtnt',
#  'multi_news',
#  'multi_nli',
#  'multi_nli_mismatch',
#  'natural_instructions',
#  'natural_questions',
#  'natural_questions_open',
#  'newsroom',
#  'nsynth',
#  'nyu_depth_v2',
#  'nyu_door_opening_surprising_effectiveness',
#  'nyu_franka_play_dataset_converted_externally_to_rlds',
#  'nyu_rot_dataset_converted_externally_to_rlds',
#  'ogbg_molpcba',
#  'omniglot',
#  'open_images_challenge2019_detection',
#  'open_images_v4',
#  'openbookqa',
#  'opinion_abstracts',
#  'opinosis',
#  'opus',
#  'oxford_flowers102',
#  'oxford_iiit_pet',
#  'para_crawl',
#  'pass',
#  'patch_camelyon',
#  'paws_wiki',
#  'paws_x_wiki',
#  'penguins',
#  'pet_finder',
#  'pg19',
#  'piqa',
#  'places365_small',
#  'placesfull',
#  'plant_leaves',
#  'plant_village',
#  'plantae_k',
#  'plex_robosuite',
#  'pneumonia_mnist',
#  'protein_net',
#  'q_re_cc',
#  'qa4mre',
#  'qasc',
#  'qm9',
#  'quac',
#  'quality',
#  'quickdraw_bitmap',
#  'race',
#  'radon',
#  'real_toxicity_prompts',
#  'reddit',
#  'reddit_disentanglement',
#  'reddit_tifu',
#  'ref_coco',
#  'resisc45',
#  'rlu_atari',
#  'rlu_atari_checkpoints',
#  'rlu_atari_checkpoints_ordered',
#  'rlu_control_suite',
#  'rlu_dmlab_explore_object_rewards_few',
#  'rlu_dmlab_explore_object_rewards_many',
#  'rlu_dmlab_rooms_select_nonmatching_object',
#  'rlu_dmlab_rooms_watermaze',
#  'rlu_dmlab_seekavoid_arena01',
#  'rlu_locomotion',
#  'rlu_rwrl',
#  'robo_set',
#  'robomimic_mg',
#  'robomimic_mh',
#  'robomimic_ph',
#  'robonet',
#  'robosuite_panda_pick_place_can',
#  'roboturk',
#  'rock_paper_scissors',
#  'rock_you',
#  's3o4d',
#  'salient_span_wikipedia',
#  'samsum',
#  'savee',
#  'scan',
#  'scene_parse150',
#  'schema_guided_dialogue',
#  'sci_tail',
#  'scicite',
#  'scientific_papers',
#  'scrolls',
#  'segment_anything',
#  'sentiment140',
#  'shapes3d',
#  'sift1m',
#  'simpte',
#  'siscore',
#  'smallnorb',
#  'smart_buildings',
#  'smartwatch_gestures',
#  'snli',
#  'so2sat',
#  'speech_commands',
#  'spoc_robot',
#  'spoken_digit',
#  'squad',
#  'squad_question_generation',
#  'stanford_dogs',
#  'stanford_hydra_dataset_converted_externally_to_rlds',
#  'stanford_kuka_multimodal_dataset_converted_externally_to_rlds',
#  'stanford_mask_vit_converted_externally_to_rlds',
#  'stanford_online_products',
#  'stanford_robocook_converted_externally_to_rlds',
#  'star_cfq',
#  'starcraft_video',
#  'stl10',
#  'story_cloze',
#  'summscreen',
#  'sun397',
#  'super_glue',
#  'svhn_cropped',
#  'symmetric_solids',
#  'taco_play',
#  'tao',
#  'tatoeba',
#  'ted_hrlr_translate',
#  'ted_multi_translate',
#  'tedlium',
#  'tf_flowers',
#  'the300w_lp',
#  'tidybot',
#  'tiny_shakespeare',
#  'titanic',
#  'tokyo_u_lsmo_converted_externally_to_rlds',
#  'toto',
#  'trec',
#  'trivia_qa',
#  'tydi_qa',
#  'uc_merced',
#  'ucf101',
#  'ucsd_kitchen_dataset_converted_externally_to_rlds',
#  'ucsd_pick_and_place_dataset_converted_externally_to_rlds',
#  'uiuc_d3field',
#  'unified_qa',
#  'universal_dependencies',
#  'unnatural_instructions',
#  'usc_cloth_sim_converted_externally_to_rlds',
#  'user_libri_audio',
#  'user_libri_text',
#  'utaustin_mutex',
#  'utokyo_pr2_opening_fridge_converted_externally_to_rlds',
#  'utokyo_pr2_tabletop_manipulation_converted_externally_to_rlds',
#  'utokyo_saytap_converted_externally_to_rlds',
#  'utokyo_xarm_bimanual_converted_externally_to_rlds',
#  'utokyo_xarm_pick_and_place_converted_externally_to_rlds',
#  'vctk',
#  'vima_converted_externally_to_rlds',
#  'viola',
#  'visual_domain_decathlon',
#  'voc',
#  'voxceleb',
#  'voxforge',
#  'wake_vision',
#  'waymo_open_dataset',
#  'web_graph',
#  'web_nlg',
#  'web_questions',
#  'webvid',
#  'wider_face',
#  'wiki40b',
#  'wiki_auto',
#  'wiki_bio',
#  'wiki_dialog',
#  'wiki_table_questions',
#  'wiki_table_text',
#  'wikiann',
#  'wikihow',
#  'wikipedia',
#  'wikipedia_toxicity_subtypes',
#  'wine_quality',
#  'winogrande',
#  'wit',
#  'wit_kaggle',
#  'wmt13_translate',
#  'wmt14_translate',
#  'wmt15_translate',
#  'wmt16_translate',
#  'wmt17_translate',
#  'wmt18_translate',
#  'wmt19_translate',
#  'wmt_t2t_translate',
#  'wmt_translate',
#  'wordnet',
#  'wsc273',
#  'xnli',
#  'xquad',
#  'xsum',
#  'xtreme_pawsx',
#  'xtreme_pos',
#  'xtreme_s',
#  'xtreme_xnli',
#  'yahoo_ltrc',
#  'yelp_polarity_reviews',
#  'yes_no',
#  'youtube_vis']

# %% [markdown]
# Tried to download dataset using tfds, but it returns a 404 error.

# %%
# ds = tfds.load('cars196', split='train', shuffle_files=True)
# assert isinstance(ds, tf.data.Dataset)
# print(ds)

# %% [markdown]
# Looking through the mat file

# %%
# checking the keys of the mat file
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'annotations', 'class_names'])

# %%
# looking through all the keys
data['__header__']
# Out:
# b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sat Feb 28 19:34:55 2015'

# %%
data['__version__']
# Out:
# '1.0'

# %%
data['__globals__']
# Out:
# []

# %%
data['annotations']
# Out:
# array([[(array(['car_ims/000001.jpg'], dtype='<U18'), array([[112]], dtype=uint8), array([[7]], dtype=uint8), array([[853]], dtype=uint16), array([[717]], dtype=uint16), array([[1]], dtype=uint8), array([[0]], dtype=uint8)),
#         (array(['car_ims/000002.jpg'], dtype='<U18'), array([[48]], dtype=uint8), array([[24]], dtype=uint8), array([[441]], dtype=uint16), array([[202]], dtype=uint8), array([[1]], dtype=uint8), array([[0]], dtype=uint8)),
#         (array(['car_ims/000003.jpg'], dtype='<U18'), array([[7]], dtype=uint8), array([[4]], dtype=uint8), array([[277]], dtype=uint16), array([[180]], dtype=uint8), array([[1]], dtype=uint8), array([[0]], dtype=uint8)),
#         ...,
#         (array(['car_ims/016183.jpg'], dtype='<U18'), array([[25]], dtype=uint8), array([[32]], dtype=uint8), array([[587]], dtype=uint16), array([[359]], dtype=uint16), array([[196]], dtype=uint8), array([[1]], dtype=uint8)),
#         (array(['car_ims/016184.jpg'], dtype='<U18'), array([[56]], dtype=uint8), array([[60]], dtype=uint8), array([[208]], dtype=uint8), array([[186]], dtype=uint8), array([[196]], dtype=uint8), array([[1]], dtype=uint8)),
#         (array(['car_ims/016185.jpg'], dtype='<U18'), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[200]], dtype=uint8), array([[131]], dtype=uint8), array([[196]], dtype=uint8), array([[1]], dtype=uint8))]],
#       dtype=[('relative_im_path', 'O'), ('bbox_x1', 'O'), ('bbox_y1', 'O'), ('bbox_x2', 'O'), ('bbox_y2', 'O'), ('class', 'O'), ('test', 'O')])

# %%
# finding what's the type of data in annotation
print(data['annotations'][0].dtype)
# Out:
# [('relative_im_path', 'O'), ('bbox_x1', 'O'), ('bbox_y1', 'O'), ('bbox_x2', 'O'), ('bbox_y2', 'O'), ('class', 'O'), ('test', 'O')]

# %%
data['class_names']
# Out:
# array([[array(['AM General Hummer SUV 2000'], dtype='<U26'),
#         array(['Acura RL Sedan 2012'], dtype='<U19'),
#         array(['Acura TL Sedan 2012'], dtype='<U19'),
#         array(['Acura TL Type-S 2008'], dtype='<U20'),
#         array(['Acura TSX Sedan 2012'], dtype='<U20'),
#         array(['Acura Integra Type R 2001'], dtype='<U25'),
#         array(['Acura ZDX Hatchback 2012'], dtype='<U24'),
#         array(['Aston Martin V8 Vantage Convertible 2012'], dtype='<U40'),
#         array(['Aston Martin V8 Vantage Coupe 2012'], dtype='<U34'),
#         array(['Aston Martin Virage Convertible 2012'], dtype='<U36'),
#         array(['Aston Martin Virage Coupe 2012'], dtype='<U30'),
#         array(['Audi RS 4 Convertible 2008'], dtype='<U26'),
#         array(['Audi A5 Coupe 2012'], dtype='<U18'),
#         array(['Audi TTS Coupe 2012'], dtype='<U19'),
#         array(['Audi R8 Coupe 2012'], dtype='<U18'),
#         array(['Audi V8 Sedan 1994'], dtype='<U18'),
#         array(['Audi 100 Sedan 1994'], dtype='<U19'),
#         array(['Audi 100 Wagon 1994'], dtype='<U19'),
#         array(['Audi TT Hatchback 2011'], dtype='<U22'),
#         array(['Audi S6 Sedan 2011'], dtype='<U18'),
#         array(['Audi S5 Convertible 2012'], dtype='<U24'),
#         array(['Audi S5 Coupe 2012'], dtype='<U18'),
#         array(['Audi S4 Sedan 2012'], dtype='<U18'),
#         array(['Audi S4 Sedan 2007'], dtype='<U18'),
#         array(['Audi TT RS Coupe 2012'], dtype='<U21'),
#         array(['BMW ActiveHybrid 5 Sedan 2012'], dtype='<U29'),
#         array(['BMW 1 Series Convertible 2012'], dtype='<U29'),
#         array(['BMW 1 Series Coupe 2012'], dtype='<U23'),
#         array(['BMW 3 Series Sedan 2012'], dtype='<U23'),
#         array(['BMW 3 Series Wagon 2012'], dtype='<U23'),
#         array(['BMW 6 Series Convertible 2007'], dtype='<U29'),
#         array(['BMW X5 SUV 2007'], dtype='<U15'),
#         array(['BMW X6 SUV 2012'], dtype='<U15'),
#         array(['BMW M3 Coupe 2012'], dtype='<U17'),
#         array(['BMW M5 Sedan 2010'], dtype='<U17'),
#         array(['BMW M6 Convertible 2010'], dtype='<U23'),
#         array(['BMW X3 SUV 2012'], dtype='<U15'),
#         array(['BMW Z4 Convertible 2012'], dtype='<U23'),
#         array(['Bentley Continental Supersports Conv. Convertible 2012'],
#               dtype='<U54')                                              ,
#         array(['Bentley Arnage Sedan 2009'], dtype='<U25'),
#         array(['Bentley Mulsanne Sedan 2011'], dtype='<U27'),
#         array(['Bentley Continental GT Coupe 2012'], dtype='<U33'),
#         array(['Bentley Continental GT Coupe 2007'], dtype='<U33'),
#         array(['Bentley Continental Flying Spur Sedan 2007'], dtype='<U42'),
#         array(['Bugatti Veyron 16.4 Convertible 2009'], dtype='<U36'),
#         array(['Bugatti Veyron 16.4 Coupe 2009'], dtype='<U30'),
#         array(['Buick Regal GS 2012'], dtype='<U19'),
#         array(['Buick Rainier SUV 2007'], dtype='<U22'),
#         array(['Buick Verano Sedan 2012'], dtype='<U23'),
#         array(['Buick Enclave SUV 2012'], dtype='<U22'),
#         array(['Cadillac CTS-V Sedan 2012'], dtype='<U25'),
#         array(['Cadillac SRX SUV 2012'], dtype='<U21'),
#         array(['Cadillac Escalade EXT Crew Cab 2007'], dtype='<U35'),
#         array(['Chevrolet Silverado 1500 Hybrid Crew Cab 2012'], dtype='<U45'),
#         array(['Chevrolet Corvette Convertible 2012'], dtype='<U35'),
#         array(['Chevrolet Corvette ZR1 2012'], dtype='<U27'),
#         array(['Chevrolet Corvette Ron Fellows Edition Z06 2007'], dtype='<U47'),
#         array(['Chevrolet Traverse SUV 2012'], dtype='<U27'),
#         array(['Chevrolet Camaro Convertible 2012'], dtype='<U33'),
#         array(['Chevrolet HHR SS 2010'], dtype='<U21'),
#         array(['Chevrolet Impala Sedan 2007'], dtype='<U27'),
#         array(['Chevrolet Tahoe Hybrid SUV 2012'], dtype='<U31'),
#         array(['Chevrolet Sonic Sedan 2012'], dtype='<U26'),
#         array(['Chevrolet Express Cargo Van 2007'], dtype='<U32'),
#         array(['Chevrolet Avalanche Crew Cab 2012'], dtype='<U33'),
#         array(['Chevrolet Cobalt SS 2010'], dtype='<U24'),
#         array(['Chevrolet Malibu Hybrid Sedan 2010'], dtype='<U34'),
#         array(['Chevrolet TrailBlazer SS 2009'], dtype='<U29'),
#         array(['Chevrolet Silverado 2500HD Regular Cab 2012'], dtype='<U43'),
#         array(['Chevrolet Silverado 1500 Classic Extended Cab 2007'], dtype='<U50'),
#         array(['Chevrolet Express Van 2007'], dtype='<U26'),
#         array(['Chevrolet Monte Carlo Coupe 2007'], dtype='<U32'),
#         array(['Chevrolet Malibu Sedan 2007'], dtype='<U27'),
#         array(['Chevrolet Silverado 1500 Extended Cab 2012'], dtype='<U42'),
#         array(['Chevrolet Silverado 1500 Regular Cab 2012'], dtype='<U41'),
#         array(['Chrysler Aspen SUV 2009'], dtype='<U23'),
#         array(['Chrysler Sebring Convertible 2010'], dtype='<U33'),
#         array(['Chrysler Town and Country Minivan 2012'], dtype='<U38'),
#         array(['Chrysler 300 SRT-8 2010'], dtype='<U23'),
#         array(['Chrysler Crossfire Convertible 2008'], dtype='<U35'),
#         array(['Chrysler PT Cruiser Convertible 2008'], dtype='<U36'),
#         array(['Daewoo Nubira Wagon 2002'], dtype='<U24'),
#         array(['Dodge Caliber Wagon 2012'], dtype='<U24'),
#         array(['Dodge Caliber Wagon 2007'], dtype='<U24'),
#         array(['Dodge Caravan Minivan 1997'], dtype='<U26'),
#         array(['Dodge Ram Pickup 3500 Crew Cab 2010'], dtype='<U35'),
#         array(['Dodge Ram Pickup 3500 Quad Cab 2009'], dtype='<U35'),
#         array(['Dodge Sprinter Cargo Van 2009'], dtype='<U29'),
#         array(['Dodge Journey SUV 2012'], dtype='<U22'),
#         array(['Dodge Dakota Crew Cab 2010'], dtype='<U26'),
#         array(['Dodge Dakota Club Cab 2007'], dtype='<U26'),
#         array(['Dodge Magnum Wagon 2008'], dtype='<U23'),
#         array(['Dodge Challenger SRT8 2011'], dtype='<U26'),
#         array(['Dodge Durango SUV 2012'], dtype='<U22'),
#         array(['Dodge Durango SUV 2007'], dtype='<U22'),
#         array(['Dodge Charger Sedan 2012'], dtype='<U24'),
#         array(['Dodge Charger SRT-8 2009'], dtype='<U24'),
#         array(['Eagle Talon Hatchback 1998'], dtype='<U26'),
#         array(['FIAT 500 Abarth 2012'], dtype='<U20'),
#         array(['FIAT 500 Convertible 2012'], dtype='<U25'),
#         array(['Ferrari FF Coupe 2012'], dtype='<U21'),
#         array(['Ferrari California Convertible 2012'], dtype='<U35'),
#         array(['Ferrari 458 Italia Convertible 2012'], dtype='<U35'),
#         array(['Ferrari 458 Italia Coupe 2012'], dtype='<U29'),
#         array(['Fisker Karma Sedan 2012'], dtype='<U23'),
#         array(['Ford F-450 Super Duty Crew Cab 2012'], dtype='<U35'),
#         array(['Ford Mustang Convertible 2007'], dtype='<U29'),
#         array(['Ford Freestar Minivan 2007'], dtype='<U26'),
#         array(['Ford Expedition EL SUV 2009'], dtype='<U27'),
#         array(['Ford Edge SUV 2012'], dtype='<U18'),
#         array(['Ford Ranger SuperCab 2011'], dtype='<U25'),
#         array(['Ford GT Coupe 2006'], dtype='<U18'),
#         array(['Ford F-150 Regular Cab 2012'], dtype='<U27'),
#         array(['Ford F-150 Regular Cab 2007'], dtype='<U27'),
#         array(['Ford Focus Sedan 2007'], dtype='<U21'),
#         array(['Ford E-Series Wagon Van 2012'], dtype='<U28'),
#         array(['Ford Fiesta Sedan 2012'], dtype='<U22'),
#         array(['GMC Terrain SUV 2012'], dtype='<U20'),
#         array(['GMC Savana Van 2012'], dtype='<U19'),
#         array(['GMC Yukon Hybrid SUV 2012'], dtype='<U25'),
#         array(['GMC Acadia SUV 2012'], dtype='<U19'),
#         array(['GMC Canyon Extended Cab 2012'], dtype='<U28'),
#         array(['Geo Metro Convertible 1993'], dtype='<U26'),
#         array(['HUMMER H3T Crew Cab 2010'], dtype='<U24'),
#         array(['HUMMER H2 SUT Crew Cab 2009'], dtype='<U27'),
#         array(['Honda Odyssey Minivan 2012'], dtype='<U26'),
#         array(['Honda Odyssey Minivan 2007'], dtype='<U26'),
#         array(['Honda Accord Coupe 2012'], dtype='<U23'),
#         array(['Honda Accord Sedan 2012'], dtype='<U23'),
#         array(['Hyundai Veloster Hatchback 2012'], dtype='<U31'),
#         array(['Hyundai Santa Fe SUV 2012'], dtype='<U25'),
#         array(['Hyundai Tucson SUV 2012'], dtype='<U23'),
#         array(['Hyundai Veracruz SUV 2012'], dtype='<U25'),
#         array(['Hyundai Sonata Hybrid Sedan 2012'], dtype='<U32'),
#         array(['Hyundai Elantra Sedan 2007'], dtype='<U26'),
#         array(['Hyundai Accent Sedan 2012'], dtype='<U25'),
#         array(['Hyundai Genesis Sedan 2012'], dtype='<U26'),
#         array(['Hyundai Sonata Sedan 2012'], dtype='<U25'),
#         array(['Hyundai Elantra Touring Hatchback 2012'], dtype='<U38'),
#         array(['Hyundai Azera Sedan 2012'], dtype='<U24'),
#         array(['Infiniti G Coupe IPL 2012'], dtype='<U25'),
#         array(['Infiniti QX56 SUV 2011'], dtype='<U22'),
#         array(['Isuzu Ascender SUV 2008'], dtype='<U23'),
#         array(['Jaguar XK XKR 2012'], dtype='<U18'),
#         array(['Jeep Patriot SUV 2012'], dtype='<U21'),
#         array(['Jeep Wrangler SUV 2012'], dtype='<U22'),
#         array(['Jeep Liberty SUV 2012'], dtype='<U21'),
#         array(['Jeep Grand Cherokee SUV 2012'], dtype='<U28'),
#         array(['Jeep Compass SUV 2012'], dtype='<U21'),
#         array(['Lamborghini Reventon Coupe 2008'], dtype='<U31'),
#         array(['Lamborghini Aventador Coupe 2012'], dtype='<U32'),
#         array(['Lamborghini Gallardo LP 570-4 Superleggera 2012'], dtype='<U47'),
#         array(['Lamborghini Diablo Coupe 2001'], dtype='<U29'),
#         array(['Land Rover Range Rover SUV 2012'], dtype='<U31'),
#         array(['Land Rover LR2 SUV 2012'], dtype='<U23'),
#         array(['Lincoln Town Car Sedan 2011'], dtype='<U27'),
#         array(['MINI Cooper Roadster Convertible 2012'], dtype='<U37'),
#         array(['Maybach Landaulet Convertible 2012'], dtype='<U34'),
#         array(['Mazda Tribute SUV 2011'], dtype='<U22'),
#         array(['McLaren MP4-12C Coupe 2012'], dtype='<U26'),
#         array(['Mercedes-Benz 300-Class Convertible 1993'], dtype='<U40'),
#         array(['Mercedes-Benz C-Class Sedan 2012'], dtype='<U32'),
#         array(['Mercedes-Benz SL-Class Coupe 2009'], dtype='<U33'),
#         array(['Mercedes-Benz E-Class Sedan 2012'], dtype='<U32'),
#         array(['Mercedes-Benz S-Class Sedan 2012'], dtype='<U32'),
#         array(['Mercedes-Benz Sprinter Van 2012'], dtype='<U31'),
#         array(['Mitsubishi Lancer Sedan 2012'], dtype='<U28'),
#         array(['Nissan Leaf Hatchback 2012'], dtype='<U26'),
#         array(['Nissan NV Passenger Van 2012'], dtype='<U28'),
#         array(['Nissan Juke Hatchback 2012'], dtype='<U26'),
#         array(['Nissan 240SX Coupe 1998'], dtype='<U23'),
#         array(['Plymouth Neon Coupe 1999'], dtype='<U24'),
#         array(['Porsche Panamera Sedan 2012'], dtype='<U27'),
#         array(['Ram C/V Cargo Van Minivan 2012'], dtype='<U30'),
#         array(['Rolls-Royce Phantom Drophead Coupe Convertible 2012'],
#               dtype='<U51')                                           ,
#         array(['Rolls-Royce Ghost Sedan 2012'], dtype='<U28'),
#         array(['Rolls-Royce Phantom Sedan 2012'], dtype='<U30'),
#         array(['Scion xD Hatchback 2012'], dtype='<U23'),
#         array(['Spyker C8 Convertible 2009'], dtype='<U26'),
#         array(['Spyker C8 Coupe 2009'], dtype='<U20'),
#         array(['Suzuki Aerio Sedan 2007'], dtype='<U23'),
#         array(['Suzuki Kizashi Sedan 2012'], dtype='<U25'),
#         array(['Suzuki SX4 Hatchback 2012'], dtype='<U25'),
#         array(['Suzuki SX4 Sedan 2012'], dtype='<U21'),
#         array(['Tesla Model S Sedan 2012'], dtype='<U24'),
#         array(['Toyota Sequoia SUV 2012'], dtype='<U23'),
#         array(['Toyota Camry Sedan 2012'], dtype='<U23'),
#         array(['Toyota Corolla Sedan 2012'], dtype='<U25'),
#         array(['Toyota 4Runner SUV 2012'], dtype='<U23'),
#         array(['Volkswagen Golf Hatchback 2012'], dtype='<U30'),
#         array(['Volkswagen Golf Hatchback 1991'], dtype='<U30'),
#         array(['Volkswagen Beetle Hatchback 2012'], dtype='<U32'),
#         array(['Volvo C30 Hatchback 2012'], dtype='<U24'),
#         array(['Volvo 240 Sedan 1993'], dtype='<U20'),
#         array(['Volvo XC90 SUV 2007'], dtype='<U19'),
#         array(['smart fortwo Convertible 2012'], dtype='<U29')]],
#       dtype=object)

# %% [markdown]
# Extracting the information in annotations

# %%
annotations = data['annotations'][0]  # Array of all entries
img_num = np.array([entry['relative_im_path'][0].split('/')[-1].split('.')[0] for entry in annotations])
bbox_x1 = np.array([entry['bbox_x1'][0][0] for entry in annotations])
bbox_y1 = np.array([entry['bbox_y1'][0][0] for entry in annotations])
bbox_x2 = np.array([entry['bbox_x2'][0][0] for entry in annotations])
bbox_y2 = np.array([entry['bbox_y2'][0][0] for entry in annotations])
classes = np.array([entry['class'][0][0] for entry in annotations]) - 1  # Adjust to 0-based indexing
test_flags = np.array([entry['test'][0][0] for entry in annotations])

# %% [markdown]
# making sure that the length of all the list matches

# %%
print(len(img_num))
print(len(bbox_x1))
print(len(bbox_y1))
print(len(bbox_x2))
print(len(bbox_y2))
print(len(classes))
print(len(test_flags))
# Out:
# 16185
# 16185
# 16185
# 16185
# 16185
# 16185
# 16185

# %% [markdown]
# checking if the images downloaded matches annotations, and split the images according to train and test folders.
#
# #### 1 is for Training data
# #### 2 is for Testing data
#
# TrainTestSplit will save which folder the img is located and the location (E.g.): \
# [[1, 'data/cars196/train\\AM General Hummer SUV 2000\\000001.jpg']
#
# this process takes up time when running the program, so i decided to store the information in a txt file to save time.

# %%
dataset_path_train = "data/cars196/train/"
dataset_path_test = "data/cars196/test/"
output_file = "data/train_test_split.txt"  # Output file path

trainTestSplit = []
trainNo = 0
testNo = 0

if os.path.exists(output_file):
    # If the output file exists, read from it
    print(f"File {output_file} exists. Loading data...")
    with open(output_file, "r") as f:
        for line in f:
            split_type, path = line.strip().split("\t")
            trainTestSplit.append([int(split_type), path])
            if int(split_type) == 1:
                trainNo += 1
            elif int(split_type) == 2:
                testNo += 1
else:
    # If the output file doesn't exist, generate the split
    print(f"File {output_file} does not exist. Generating train-test split...")
    for path in img_num:
        train_path = glob.glob(os.path.join(dataset_path_train, '*/', path + '.jpg'))
        test_path = glob.glob(os.path.join(dataset_path_test, '*/', path + '.jpg'))
        if train_path:
            train_path = train_path[0].replace("\\", "/")
            trainTestSplit.append([1, train_path])
            print(f"Image found in train: {train_path}")
            trainNo += 1
        elif test_path:
            test_path = test_path[0].replace("\\", "/")
            trainTestSplit.append([2, test_path])
            print(f"Image found in test: {test_path}")
            testNo += 1
        else:
            trainTestSplit.append([0, path + '.jpg'])
            print(f"Image not found: {path}.jpg")
    
    # Save to a text file
    os.makedirs("data", exist_ok=True)  # Ensure the 'data' directory exists
    with open(output_file, "w") as f:
        for entry in trainTestSplit:
            f.write(f"{entry[0]}\t{entry[1]}\n")
    print(f"Saved train-test split information to {output_file}")

# Check total count
total_count = len(trainTestSplit)
if total_count == 16185:
    print("Total images match the expected count of 16185.")
else:
    print(f"Total images: {total_count}, which is not the expected count of 16185.")

# Print summary
print(f"Number of Training imgs: {trainNo}\nNumber of Testing imgs: {testNo}\nTotal: {trainNo + testNo}")
# Out:
# File data/train_test_split.txt does not exist. Generating train-test split...
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000001.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000002.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000003.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000004.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000005.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000006.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000007.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000008.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000009.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000010.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000011.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000012.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000013.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000014.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000015.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000016.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000017.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000018.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000019.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000020.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000021.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000022.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000023.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000024.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000025.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000026.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000027.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000028.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000029.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000030.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000031.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000032.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000033.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000034.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000035.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000036.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000037.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000038.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000039.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000040.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000041.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000042.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000043.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000044.jpg
# Image found in train: data/cars196/train/AM General Hummer SUV 2000/000045.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000046.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000047.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000048.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000049.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000050.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000051.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000052.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000053.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000054.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000055.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000056.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000057.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000058.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000059.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000060.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000061.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000062.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000063.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000064.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000065.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000066.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000067.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000068.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000069.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000070.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000071.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000072.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000073.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000074.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000075.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000076.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000077.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000078.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000079.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000080.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000081.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000082.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000083.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000084.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000085.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000086.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000087.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000088.jpg
# Image found in test: data/cars196/test/AM General Hummer SUV 2000/000089.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000090.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000091.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000092.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000093.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000094.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000095.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000096.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000097.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000098.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000099.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000100.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000101.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000102.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000103.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000104.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000105.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000106.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000107.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000108.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000109.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000110.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000111.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000112.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000113.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000114.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000115.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000116.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000117.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000118.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000119.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000120.jpg
# Image found in train: data/cars196/train/Acura RL Sedan 2012/000121.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000122.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000123.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000124.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000125.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000126.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000127.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000128.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000129.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000130.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000131.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000132.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000133.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000134.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000135.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000136.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000137.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000138.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000139.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000140.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000141.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000142.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000143.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000144.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000145.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000146.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000147.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000148.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000149.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000150.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000151.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000152.jpg
# Image found in test: data/cars196/test/Acura RL Sedan 2012/000153.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000154.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000155.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000156.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000157.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000158.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000159.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000160.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000161.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000162.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000163.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000164.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000165.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000166.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000167.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000168.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000169.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000170.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000171.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000172.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000173.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000174.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000175.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000176.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000177.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000178.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000179.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000180.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000181.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000182.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000183.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000184.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000185.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000186.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000187.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000188.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000189.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000190.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000191.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000192.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000193.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000194.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000195.jpg
# Image found in train: data/cars196/train/Acura TL Sedan 2012/000196.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000197.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000198.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000199.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000200.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000201.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000202.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000203.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000204.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000205.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000206.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000207.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000208.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000209.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000210.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000211.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000212.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000213.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000214.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000215.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000216.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000217.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000218.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000219.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000220.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000221.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000222.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000223.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000224.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000225.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000226.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000227.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000228.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000229.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000230.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000231.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000232.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000233.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000234.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000235.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000236.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000237.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000238.jpg
# Image found in test: data/cars196/test/Acura TL Sedan 2012/000239.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000240.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000241.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000242.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000243.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000244.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000245.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000246.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000247.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000248.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000249.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000250.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000251.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000252.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000253.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000254.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000255.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000256.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000257.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000258.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000259.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000260.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000261.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000262.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000263.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000264.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000265.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000266.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000267.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000268.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000269.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000270.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000271.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000272.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000273.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000274.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000275.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000276.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000277.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000278.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000279.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000280.jpg
# Image found in train: data/cars196/train/Acura TL Type-S 2008/000281.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000282.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000283.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000284.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000285.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000286.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000287.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000288.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000289.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000290.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000291.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000292.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000293.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000294.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000295.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000296.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000297.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000298.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000299.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000300.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000301.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000302.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000303.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000304.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000305.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000306.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000307.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000308.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000309.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000310.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000311.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000312.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000313.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000314.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000315.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000316.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000317.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000318.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000319.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000320.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000321.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000322.jpg
# Image found in test: data/cars196/test/Acura TL Type-S 2008/000323.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000324.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000325.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000326.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000327.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000328.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000329.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000330.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000331.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000332.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000333.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000334.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000335.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000336.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000337.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000338.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000339.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000340.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000341.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000342.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000343.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000344.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000345.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000346.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000347.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000348.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000349.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000350.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000351.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000352.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000353.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000354.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000355.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000356.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000357.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000358.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000359.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000360.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000361.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000362.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000363.jpg
# Image found in train: data/cars196/train/Acura TSX Sedan 2012/000364.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000365.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000366.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000367.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000368.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000369.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000370.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000371.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000372.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000373.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000374.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000375.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000376.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000377.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000378.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000379.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000380.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000381.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000382.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000383.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000384.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000385.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000386.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000387.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000388.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000389.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000390.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000391.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000392.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000393.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000394.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000395.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000396.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000397.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000398.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000399.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000400.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000401.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000402.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000403.jpg
# Image found in test: data/cars196/test/Acura TSX Sedan 2012/000404.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000405.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000406.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000407.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000408.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000409.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000410.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000411.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000412.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000413.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000414.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000415.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000416.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000417.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000418.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000419.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000420.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000421.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000422.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000423.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000424.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000425.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000426.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000427.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000428.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000429.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000430.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000431.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000432.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000433.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000434.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000435.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000436.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000437.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000438.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000439.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000440.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000441.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000442.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000443.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000444.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000445.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000446.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000447.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000448.jpg
# Image found in train: data/cars196/train/Acura Integra Type R 2001/000449.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000450.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000451.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000452.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000453.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000454.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000455.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000456.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000457.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000458.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000459.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000460.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000461.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000462.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000463.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000464.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000465.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000466.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000467.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000468.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000469.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000470.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000471.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000472.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000473.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000474.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000475.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000476.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000477.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000478.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000479.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000480.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000481.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000482.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000483.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000484.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000485.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000486.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000487.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000488.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000489.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000490.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000491.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000492.jpg
# Image found in test: data/cars196/test/Acura Integra Type R 2001/000493.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000494.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000495.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000496.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000497.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000498.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000499.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000500.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000501.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000502.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000503.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000504.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000505.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000506.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000507.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000508.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000509.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000510.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000511.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000512.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000513.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000514.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000515.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000516.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000517.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000518.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000519.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000520.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000521.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000522.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000523.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000524.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000525.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000526.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000527.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000528.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000529.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000530.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000531.jpg
# Image found in train: data/cars196/train/Acura ZDX Hatchback 2012/000532.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000533.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000534.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000535.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000536.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000537.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000538.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000539.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000540.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000541.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000542.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000543.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000544.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000545.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000546.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000547.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000548.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000549.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000550.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000551.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000552.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000553.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000554.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000555.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000556.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000557.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000558.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000559.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000560.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000561.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000562.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000563.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000564.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000565.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000566.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000567.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000568.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000569.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000570.jpg
# Image found in test: data/cars196/test/Acura ZDX Hatchback 2012/000571.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000572.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000573.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000574.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000575.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000576.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000577.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000578.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000579.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000580.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000581.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000582.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000583.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000584.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000585.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000586.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000587.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000588.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000589.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000590.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000591.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000592.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000593.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000594.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000595.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000596.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000597.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000598.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000599.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000600.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000601.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000602.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000603.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000604.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000605.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000606.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000607.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000608.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000609.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000610.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000611.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000612.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000613.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000614.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000615.jpg
# Image found in train: data/cars196/train/Aston Martin V8 Vantage Convertible 2012/000616.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000617.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000618.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000619.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000620.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000621.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000622.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000623.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000624.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000625.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000626.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000627.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000628.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000629.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000630.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000631.jpg
# Image found in test: data/cars196/test/Aston Martin V8 Vantage Convertible 2012/000632.jpg
# ...
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015975.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015976.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015977.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015978.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015979.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015980.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015981.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015982.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015983.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015984.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015985.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015986.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015987.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015988.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015989.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015990.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015991.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015992.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015993.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015994.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015995.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015996.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015997.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015998.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/015999.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016000.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016001.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016002.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016003.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016004.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016005.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016006.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016007.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016008.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016009.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016010.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016011.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016012.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016013.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016014.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016015.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016016.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016017.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016018.jpg
# Image found in test: data/cars196/test/Volvo 240 Sedan 1993/016019.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016020.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016021.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016022.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016023.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016024.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016025.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016026.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016027.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016028.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016029.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016030.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016031.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016032.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016033.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016034.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016035.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016036.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016037.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016038.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016039.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016040.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016041.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016042.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016043.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016044.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016045.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016046.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016047.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016048.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016049.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016050.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016051.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016052.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016053.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016054.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016055.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016056.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016057.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016058.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016059.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016060.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016061.jpg
# Image found in train: data/cars196/train/Volvo XC90 SUV 2007/016062.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016063.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016064.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016065.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016066.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016067.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016068.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016069.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016070.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016071.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016072.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016073.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016074.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016075.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016076.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016077.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016078.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016079.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016080.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016081.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016082.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016083.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016084.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016085.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016086.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016087.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016088.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016089.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016090.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016091.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016092.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016093.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016094.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016095.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016096.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016097.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016098.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016099.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016100.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016101.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016102.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016103.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016104.jpg
# Image found in test: data/cars196/test/Volvo XC90 SUV 2007/016105.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016106.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016107.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016108.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016109.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016110.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016111.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016112.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016113.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016114.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016115.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016116.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016117.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016118.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016119.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016120.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016121.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016122.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016123.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016124.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016125.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016126.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016127.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016128.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016129.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016130.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016131.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016132.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016133.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016134.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016135.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016136.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016137.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016138.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016139.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016140.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016141.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016142.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016143.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016144.jpg
# Image found in train: data/cars196/train/smart fortwo Convertible 2012/016145.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016146.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016147.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016148.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016149.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016150.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016151.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016152.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016153.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016154.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016155.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016156.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016157.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016158.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016159.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016160.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016161.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016162.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016163.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016164.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016165.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016166.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016167.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016168.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016169.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016170.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016171.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016172.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016173.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016174.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016175.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016176.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016177.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016178.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016179.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016180.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016181.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016182.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016183.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016184.jpg
# Image found in test: data/cars196/test/smart fortwo Convertible 2012/016185.jpg
# Saved train-test split information to data/train_test_split.txt
# Total images match the expected count of 16185.
# Number of Training imgs: 8144
# Number of Testing imgs: 8041
# Total: 16185

# %% [markdown]
# checking for missing images and the length of the new list.

# %%
if any(value == 0 for value in trainTestSplit):
    print("The list contains the value 0.")
else:
    print("The list does not contain the value 0.")
# check len to match previous lists
print(len(trainTestSplit))

# %%
# checking the list
print(trainTestSplit[0])

# %% [markdown]
# I understand that this dataset have 196 unique cars but I want to check the data and make sure it has the same number of unique cars as my prior knowledge on this dataset. After finishing the reggex I realised I could have just count the numbers of folders...

# %%
# Create a set to store unique car names
unique_car_names = set()

# Iterate through each entry in the list
for entry in trainTestSplit:
    path = entry[1]
    # Use regex to find text between backslashes
    match = re.search(r'\\(.*?)\\', path)
    if match:
        car_name = match.group(1)
        unique_car_names.add(car_name)
        entry.append(car_name)

# Get the count of unique car names
unique_car_count = len(unique_car_names)
print(unique_car_count)

# %%
print(unique_car_names)

# %%
print(trainTestSplit[770])

# %% [markdown]
# ### Convert everything into a list - to be converted into a dataset
# The img data I downloaded was already split, I'll just use it as it is and split the training and testing data according to the folders.

# %%
train_image_paths = []
train_labels = []

test_image_paths = []
test_labels = []

for i, entry in enumerate(trainTestSplit):
    if entry[0] == 1: 
        train_image_paths.append(entry[1])
        train_labels.append(entry[2])
    elif entry[0] == 2:
        test_image_paths.append(entry[1])
        test_labels.append(entry[2])

# %% [markdown]
# ### Pre-train model with imageNet
# After going through two articles on pre-train model I realised I had a misconception about pre-train models from its name - pre-trained models might interfer with the results of the output negatively due to it being trained in other aspect. But from what i have read it improves the models in a way that decrease the training time while being smaller than 'state-of-the-art' moodels. ([Article 1](https://arxiv.org/pdf/2104.00298))  Having pre-trained models is not a necessity but can be helpful on smaller data (less than 10k images). ([Article 2](https://openaccess.thecvf.com/content_ICCV_2019/papers/He_Rethinking_ImageNet_Pre-Training_ICCV_2019_paper.pdf))

# %% [markdown]
# Used this to check image size - almost all the images have different sizes

# %%
# sizeDict = {}
# for Type, Path, car in trainTestSplit:
#     img = Image.open(Path)
#     width = img.width
#     height = img.height
#     if f"{height}.{width}" not in sizeDict:
#         sizeDict.update({f"{height}.{width}":1})
#     else:
#         sizeDict[f"{height}.{width}"] += 1

# print(sizeDict)

# %%
# For EfficientNet-B0 the size of the image is 224x224
IMG_SIZE = 224
BATCH_SIZE = 64

# %% [markdown]
# Create tensorflow dataset from image paths and labels

# %%
size = (IMG_SIZE, IMG_SIZE)
ds_train = tf.data.Dataset.from_tensor_slices((train_image_paths, train_labels))
ds_test = tf.data.Dataset.from_tensor_slices((test_image_paths, test_labels))

# %% [markdown]
# Using LabelEncoder to encode the labels to a corresponding number

# %%
# Convert the set to a list
label_list = list(unique_car_names)
sorted(label_list) 

# Fit LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(label_list)

# Get the mapping between labels and numbers
label_to_number = dict(zip(label_list, label_encoder.transform(label_list)))
# Sort by value (ascending)
sorted_dict = dict(sorted(label_to_number.items(), key=lambda item: item[1]))
# save the dict to a txt file
with open('data/label_to_number.txt', 'w') as file:
    for key, value in sorted_dict.items():
        file.write(f"{key}: {value}\n")

print(label_to_number)

# %%
# Function to load and preprocess images and label
def load_and_preprocess_image(image_path, label, target_size=(224, 224)):
    image = tf.io.read_file(image_path) # Load
    image = tf.image.decode_jpeg(image, channels=3) # Decode
    image = tf.image.resize(image, target_size) # Resize
    image = image / 255.0 # Normalize
    
    # convert string label to int
    label_number = tf.py_function(func=lookup_label, inp=[label], Tout=tf.int32)
    # Make sure label is scalar
    label_number = tf.reshape(label_number, ())
    
    return image, label_number

def lookup_label(label):
    # Convert Tensor label to Python string
    label_str = label.numpy().decode('utf-8')
    # Look up the label in the dictionary
    return label_to_number[label_str]

# %%
# Apply preprocessing to the dataset
target_size = (224, 224)
ds_train = ds_train.map(lambda image_path, label: load_and_preprocess_image(image_path, label, target_size))
ds_test = ds_test.map(lambda image_path, label: load_and_preprocess_image(image_path, label, target_size))

# %%
ds_train = ds_train.shuffle(buffer_size=len(train_image_paths)).batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
ds_test = ds_test.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ### Data augmentaion
# preprocessing layers APIs for image augmentation

# %%
data_augmentation = Sequential([
    layers.RandomRotation(factor=0.15),
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
    layers.RandomFlip(),
    layers.RandomContrast(factor=0.1),
])

# Applying augmentation directly to the training set
ds_train = ds_train.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
base_model = EfficientNetB0(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model.trainable = False  # Freeze base model

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)  # Add augmentation here
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(unique_car_count, activation='softmax')(x)

model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# %% [markdown]
# # Train Model
# when running the first epoch, i realised my computer's CPU was running at 100% and feels like it could crash any time (music was stuttering in the background, everything became less responsive), so i decided to follow this [link](https://saturncloud.io/blog/how-to-run-jupyter-notebook-on-gpus/#1) to run jupyter notebook on my GPU instead.

# %%
model = EfficientNetB0(
    include_top=True,
    weights=None,
    classes=unique_car_count,
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()

epochs = 40  
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test)

# %%
model.save_weights("models/first_1.weights.h5")
