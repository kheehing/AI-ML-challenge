# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from werkzeug.serving import run_simple
from tensorflow.keras.models import load_model
from tensorflow.keras.applications import EfficientNetB0
from flask import Flask, request, jsonify

# %% [markdown]
# ### Loading .Weights.h5 file

# %%
# model
model = EfficientNetB0(
    include_top=True,
    weights=None,
    classes=196,
    input_shape=(224, 224, 3),
)

# loading weight
model.load_weights('models/first.weights.h5')

# %%
print(model.summary())
# Out:
# Model: "efficientnetb0"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ rescaling (Rescaling)         │ (None, 224, 224, 3)       │               0 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ normalization (Normalization) │ (None, 224, 224, 3)       │               7 │ rescaling[0][0]            │
# ...

# %% [markdown]
# ### Creating API

# %%
app = Flask(__name__)

# Load the pre-trained model
model = load_model("models/first.weights.h5")

IMG_SIZE = 224  # Replace with the correct image size your model expects

@app.route('/predict', methods=['POST'])
def predict():
    try:
        # Get the input data from the request
        data = request.json
        if 'input' not in data:
            return jsonify({'error': 'Input data not found in request'}), 400

        # Decode and preprocess the input image
        img_data = base64.b64decode(data['input'])  # Assuming input is a base64-encoded image
        nparr = np.frombuffer(img_data, np.uint8)
        img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))  # Resize to model's input size
        img = img / 255.0  # Normalize if required by the model
        img = np.expand_dims(img, axis=0)  # Add batch dimension

        # Perform prediction
        predictions = model.predict(img)

        # Return predictions
        return jsonify({'predictions': predictions.tolist()})
    except Exception as e:
        return jsonify({'error': str(e)}), 500
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 app = Flask(__name__)
#       3 # Load the pre-trained model
# ----> 4 model = load_model("models/first.weights.h5")  # Replace with your model file path
#       6 IMG_SIZE = 224  # Replace with the correct image size your model expects
#       8 @app.route('/predict', methods=['POST'])
#       9 def predict():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\saving\saving_api.py:189, in load_model(filepath, custom_objects, compile, safe_mode)
#     182     return saving_lib.load_model(
#     183         filepath,
#     184         custom_objects=custom_objects,
#     185         compile=compile,
#     186         safe_mode=safe_mode,
#     187     )
#     188 if str(filepath).endswith((".h5", ".hdf5")):
# --> 189     return legacy_h5_format.load_model_from_hdf5(
# ...

# %%
from werkzeug.serving import run_simple

run_simple('localhost', 5000, app)
